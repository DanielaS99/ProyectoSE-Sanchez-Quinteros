# %% [markdown]
# # Entrenando un modelo de IA usando datos EMG

# %%
# Importar las librerias necesaria
import pandas as pd
import numpy as np
import os
import time

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from keras.layers import Input, Dense, Dropout
import sklearn
from sklearn.metrics import confusion_matrix
from tensorflow import lite

import matplotlib.pyplot as plt
import seaborn as sn

# %%
# Nombre de los sensores empleados.
emg_columns = ["AX", "AY", "AZ", "GX", "GY", "GZ"]

# Asignar a cada carpeta un identificador correspondiente a una tarea motora.
FOLDER_2_LABEL = {"task1": 0, "task2": 1, "task3": 2, "task4": 3}

# Frecuencia de Muestreo de la señal.
ORIGINAL_FREC = 100 # Hz
# Tiempo de muestreo de un sample.
SAMPLE_TIME = 2.5
TOTAL_DATA = int(SAMPLE_TIME*ORIGINAL_FREC)

# Path donde se almacenan los datos.
MAIN_PATH = "data"

# Path para guardar las características calculadas.
FEATURES_PATH = "Features.csv"

# %%
def filter_signal(df: pd.DataFrame, window_size: int):
    """
    Filtrar la señal usando el método de la media móvil.
    Params:
        df: contiene los datos emg, siendo
            cada columna el registro de un
            sensor. 
        window_size: tamano de la ventana móvil.
    Return:
        df_filtered (Dataframe): contiene los datos EMG 
                                 filtrados por columna.
    """
    df_filtered = df.rolling(window_size).mean()
    df_filtered.dropna(inplace=True)
    return df_filtered

def normalize_columns(df: pd.DataFrame):
    """
    Normalizar las columnas aplicando el 
    método de normalización min-max.
    """
    df_normalized = (df-df.min())/(df.max()-df.min())
    return df_normalized

def calculate_features(df: pd.DataFrame, label: int):
    """
    Calcula las características de la señal por sensor,
    usando el método del valor RMS.
    Params:
        df: contiene los datos emg, siendo
            cada columna el registro de un
            sensor.
        label: el identificador de la tarea motora a
               la que corresponde esa señal.
    Return:
        features_list (list): contiene el label de la
                              señal y las características. 
    """
    features_list = []
    for sensor in emg_columns:
        for i in range(0, 250, 50):
            features_list.append(np.sqrt(np.mean(df.iloc[i:i+50][sensor]**2)))
    features_list.insert(0, label)
    return features_list

# %% [markdown]
# ## Filtrado - Normalización - Extracción de características

# %% [markdown]
# Nota: Para calcular y usar el valor RMS de una senal como entrada de un modelo, se debe procurar escoger una ventana no tan grande, ya que la senal podría dejar de ser representativa.

# %%
# El tamano de la ventana para calcular las características.
WINDOW_RMS = 50

# El tamano de la ventana inicial debe ser divisible para el tamano de la ventana RMS.
assert(TOTAL_DATA % WINDOW_RMS == 0)

# Generar una lista que contenga los nombres de las características a calcular.
features_column = ['RMS' + str(x) + '_' + sensor for sensor in emg_columns for x in range(WINDOW_RMS,TOTAL_DATA+WINDOW_RMS, WINDOW_RMS)]
features_column.insert(0,"Label")

# Inicializar el Dataframe que contendrá las características calculadas más adelante.
df_features = pd.DataFrame(columns=features_column)

# Recorrer cada carpeta.
for folder in os.listdir(MAIN_PATH):
    folder_path = os.path.join(MAIN_PATH, folder)
    # Recorrer cada archivo de la carpeta.
    for file in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file)
        # Leer las senales EMG.
        df = pd.read_csv(file_path, names=emg_columns, index_col=False)
        # Filtrar las senales EMG.
        df_filtered = filter_signal(df, 2)
        # Normalizar las senales EMG.
        df_norm = normalize_columns(df_filtered)
        # Calcular las características del respectivo archivo.
        features = calculate_features(df_norm, FOLDER_2_LABEL[folder])
        # Agregar las características calculadas al Dataframe df_features.
        df_features.loc[len(df_features)] = features

# %%
# Escribir el Dataframe con las características.
df_features.to_csv(FEATURES_PATH, index=False)

# %% [markdown]
# ## Entrenamiento del modelo

# %%
# Definir una semilla.
RANDOM_STATE = 42

# Establecer el porcentaje para dividir la data.
TRAIN_SPLIT = 0.6
VALID_TEST_SPLIT = 0.2
assert(TRAIN_SPLIT + (2*VALID_TEST_SPLIT) == 1)

# Definir la taza de aprendizaje.
LEARNING_RATE = 0.001

# Definir el número de épocas.
EPOCHS = 200

# Definir el tamaño del batch.
BATCH_SIZE = 64

# %%
# Leer archivo con características de las señales EMG.
features_df = pd.read_csv(FEATURES_PATH)

# %%
# Convertir la columna a tipo int.
features_df["Label"] = features_df["Label"].astype(int)
# Asegurarnos de no introducir datos vacíos.
features_df.dropna(inplace=True)
# Hacer un shuffle a los datos.
features = features_df.sample(frac=1, random_state=RANDOM_STATE)
# Convertir a un arreglo de numpy (ya que el modelo trabaja con este tipo de datos).
features = features.to_numpy()

# Separar los datos entre el target (el id de la tarea motora) y las características.
# Nota: En este caso en específico se usa la función to_categorical, ya que 
# la función de pérdida que se usó en el modelo requiere de variables categóricas.
y_values = keras.utils.to_categorical(features[:,0], num_classes=4)
x_values = features[:,1:].astype('float32')

# Separar los datos en TRAINING, TESTING Y VALIDATION.
TRAIN_SPLIT =  int(TRAIN_SPLIT * features.shape[0])
TEST_SPLIT = int(VALID_TEST_SPLIT * features.shape[0] + TRAIN_SPLIT)
x_train, x_test, x_validate = np.split(x_values, [TRAIN_SPLIT, TEST_SPLIT])
y_train, y_test, y_validate = np.split(y_values, [TRAIN_SPLIT, TEST_SPLIT])

# Asegurar que la división de los datos fue exitosa.
assert(x_train.shape[0] + x_test.shape[0] + x_validate.shape[0] == features.shape[0])
# Out:
# 0

# %%
# Definir la arquitectura del modelo
model = Sequential()
model.add(Dense(60, input_shape = (x_train.shape[1],), activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(30, input_shape = (x_train.shape[1],),activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(4,activation='softmax'))

# %%
print(x_test[0])
# Out:
# [0.6066826  0.74756104 0.44965687 0.6623517  0.8946285  0.92161703
#  0.42531034 0.15812817 0.3050601  0.5011866  0.25762966 0.74854094
#  0.4093377  0.42296284 0.4174231  0.7566429  0.6272858  0.27487952
#  0.314638   0.42575115 0.6128776  0.3588915  0.7506087  0.57122135
#  0.3766102  0.86355567 0.5520827  0.57722944 0.185226   0.43545854]

# %%
# Definir la función de optimización y sus hiperparámetros.
optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE)
# Definir la función de pérdida y compilar el modelo.
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy', tf.keras.metrics.Recall(), tf.keras.metrics.Precision()])

# Entrenar el modelo
start = time.time()
history = model.fit(x_train, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE,
                            validation_data=(x_validate, y_validate))
stop = time.time()
#print(f"Total training time: {stop - start}s")
test_results = model.evaluate(x_test, y_test, verbose=1)
# Out:
# Epoch 1/200
# 4/4 [==============================] - 1s 124ms/step - loss: 1.5070 - accuracy: 0.2625 - recall: 0.0167 - precision: 0.0851 - val_loss: 1.4045 - val_accuracy: 0.2875 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00
# Epoch 2/200
# 4/4 [==============================] - 0s 11ms/step - loss: 1.4263 - accuracy: 0.2333 - recall: 0.0000e+00 - precision: 0.0000e+00 - val_loss: 1.3795 - val_accuracy: 0.2875 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00
# Epoch 3/200
# 4/4 [==============================] - 0s 12ms/step - loss: 1.3994 - accuracy: 0.2458 - recall: 0.0000e+00 - precision: 0.0000e+00 - val_loss: 1.3720 - val_accuracy: 0.3000 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00
# Epoch 4/200
# 4/4 [==============================] - 0s 13ms/step - loss: 1.3951 - accuracy: 0.2500 - recall: 0.0000e+00 - precision: 0.0000e+00 - val_loss: 1.3628 - val_accuracy: 0.4125 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00
# Epoch 5/200
# 4/4 [==============================] - 0s 11ms/step - loss: 1.
200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.8365 - accuracy: 0.7125 - recall: 0.4000 - precision: 0.8807 - val_loss: 0.6774 - val_accuracy: 0.9875 - val_recall: 0.4875 - val_precision: 1.0000
# Epoch 26/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.8154 - accuracy: 0.7125 - recall: 0.4250 - precision: 0.8571 - val_loss: 0.6447 - val_accuracy: 0.9875 - val_recall: 0.4875 - val_precision: 1.0000
# Epoch 27/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.8290 - accuracy: 0.6917 - recall: 0.4167 - precision: 0.8772 - val_loss: 0.6145 - val_accuracy: 0.9875 - val_recall: 0.5375 - val_precision: 1.0000
# Epoch 28/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.7962 - accuracy: 0.7250 - recall: 0.4667 - precision: 0.8960 - val_loss: 0.5850 - val_accuracy: 0.9875 - val_recall: 0.6000 - val_precision: 1.0000
# Epoch 29/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.7841 - accuracy: 0.7583 - recall: 0.4875 - precision: 0.8478 - val_loss: 0.5577 - val_accuracy: 0.9875 - val_recall: 0.6750 - val_precision: 1.0000
# Epoch 30/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7713 - accuracy: 0.7333 - recall: 0.4792 - precision: 0.8273 - val_loss: 0.5297 - val_accuracy: 0.9875 - val_recall: 0.7125 - val_precision: 1.0000
# Epoch 31/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6813 - accuracy: 0.7792 - recall: 0.5625 - precision: 0.8710 - val_loss: 0.5046 - val_accuracy: 0.9875 - val_recall: 0.7250 - val_precision: 1.0000
# Epoch 32/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6660 - accuracy: 0.8125 - recall: 0.5750 - precision: 0.9139 - val_loss: 0.4812 - val_accuracy: 1.0000 - val_recall: 0.7500 - val_precision: 1.0000
# Epoch 33/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6731 - accuracy: 0.7917 - recall: 0.5917 - precision: 0.8659 - val_loss: 0.4556 - val_accuracy: 1.0000 - val_recall: 0.8000 - val_precision: 1.0000
# Epoch 34/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5922 - accuracy: 0.8417 - recall: 0.6625 - precision: 0.9138 - val_loss: 0.4247 - val_accuracy: 1.0000 - val_recall: 0.8500 - val_precision: 1.0000
# Epoch 35/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6464 - accuracy: 0.7917 - recall: 0.6083 - precision: 0.9012 - val_loss: 0.3981 - val_accuracy: 1.0000 - val_recall: 0.9000 - val_precision: 1.0000
# Epoch 36/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6306 - accuracy: 0.8167 - recall: 0.6458 - precision: 0.8807 - val_loss: 0.3789 - val_accuracy: 1.0000 - val_recall: 0.9625 - val_precision: 1.0000
# Epoch 37/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5912 - accuracy: 0.8042 - recall: 0.7042 - precision: 0.9037 - val_loss: 0.3631 - val_accuracy: 1.0000 - val_recall: 0.9625 - val_precision: 1.0000
# Epoch 38/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.4964 - accuracy: 0.8875 - recall: 0.7958 - precision: 0.9227 - val_loss: 0.3356 - val_accuracy: 1.0000 - val_recall: 0.9750 - val_precision: 1.0000
# Epoch 39/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.4896 - accuracy: 0.8583 - recall: 0.7917 - precision: 0.9048 - val_loss: 0.3150 - val_accuracy: 1.0000 - val_recall: 0.9750 - val_precision: 1.0000
# Epoch 40/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5849 - accuracy: 0.8000 - recall: 0.7083 - precision: 0.8763 - val_loss: 0.2958 - val_accuracy: 1.0000 - val_recall: 0.9750 - val_precision: 1.0000
# Epoch 41/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.
-04 - val_accuracy: 1.0000 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 188/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0530 - accuracy: 0.9792 - recall: 0.9750 - precision: 0.9873 - val_loss: 6.9422e-04 - val_accuracy: 1.0000 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 189/200
# 4/4 [==============================] - 0s 60ms/step - loss: 0.0377 - accuracy: 0.9833 - recall: 0.9833 - precision: 0.9916 - val_loss: 6.2910e-04 - val_accuracy: 1.0000 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 190/200
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0662 - accuracy: 0.9708 - recall: 0.9625 - precision: 0.9830 - val_loss: 5.8606e-04 - val_accuracy: 1.0000 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 191/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0621 - accuracy: 0.9833 - recall: 0.9792 - precision: 0.9833 - val_loss: 6.0608e-04 - val_accuracy: 1.0000 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 192/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0460 - accuracy: 0.9750 - recall: 0.9750 - precision: 0.9791 - val_loss: 6.6273e-04 - val_accuracy: 1.0000 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 193/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0678 - accuracy: 0.9583 - recall: 0.9583 - precision: 0.9583 - val_loss: 6.8917e-04 - val_accuracy: 1.0000 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 194/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0482 - accuracy: 0.9792 - recall: 0.9750 - precision: 0.9832 - val_loss: 6.0790e-04 - val_accuracy: 1.0000 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 195/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0566 - accuracy: 0.9750 - recall: 0.9708 - precision: 0.9790 - val_loss: 5.3725e-04 - val_accuracy: 1.0000 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 196/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0473 - accuracy: 0.9833 - recall: 0.9792 - precision: 0.9833 - val_loss: 5.2100e-04 - val_accuracy: 1.0000 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 197/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0552 - accuracy: 0.9792 - recall: 0.9792 - precision: 0.9792 - val_loss: 5.2487e-04 - val_accuracy: 1.0000 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 198/200
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0568 - accuracy: 0.9750 - recall: 0.9750 - precision: 0.9791 - val_loss: 5.1237e-04 - val_accuracy: 1.0000 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 199/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0733 - accuracy: 0.9625 - recall: 0.9625 - precision: 0.9625 - val_loss: 5.4142e-04 - val_accuracy: 1.0000 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 200/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0310 - accuracy: 0.9875 - recall: 0.9875 - precision: 0.9916 - val_loss: 6.0877e-04 - val_accuracy: 1.0000 - val_recall: 1.0000 - val_precision: 1.0000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.0106 - accuracy: 1.0000 - recall: 0.9875 - precision: 1.0000

# %%
x = [i for i in range (0,len(history.history["loss"]))]

plt.figure(figsize=(20, 20))
fig, axs = plt.subplots(2, 2, figsize=(15,12))
axs[0, 0].plot(x, history.history["loss"])
axs[0, 0].set_title('Train Loss')
axs[0, 1].plot(x, history.history["accuracy"], 'tab:orange')
axs[0, 1].set_title('Train Accuracy')
axs[1, 0].plot(x, history.history["precision"], 'tab:green')
axs[1, 0].set_title('Train Precision')
axs[1, 1].plot(x, history.history["recall"], 'tab:red')
axs[1, 1].set_title('Train Recall')
# Out:
# Text(0.5, 1.0, 'Train Recall')

# %%
# Testear el modelo
y_pred = model.predict(x_test)
y_pred = np.argmax(y_pred, axis=-1)
y_true = np.argmax(y_test, axis=-1)

# Definir la matriz de confusión
cm = confusion_matrix(y_true, y_pred, labels=[0,1,2,3])
df_cm = pd.DataFrame(cm, range(cm.shape[0]), range(cm.shape[0]))
sn.set(font_scale=1.4)
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16})

plt.show()
# Out:
# 3/3 [==============================] - 0s 2ms/step

# %% [markdown]
# ## Conversión del modelo

# %%
# Definir la dirección donde se guardará los datos del modelo.
MODELS_DIR = 'models/'
MODEL_TFLITE = MODELS_DIR + 'model_no_quant.tflite'

# Crear la carpeta sino existe.
if not os.path.exists(MODELS_DIR):
    os.mkdir(MODELS_DIR)

# Guardar el modelo.
model.save(MODELS_DIR)

# Convertir el modelo a Tensorflow Lite.
converter = lite.TFLiteConverter.from_keras_model(model)
model_tflite = converter.convert()

# Guardar el modelo .tflite
open(MODEL_TFLITE, "wb").write(model_tflite)

# Correr esta linea de código en Linux.
# Esto se hace para transformar el modelo a un archivo fuente C (https://www.tensorflow.org/lite/microcontrollers/build_convert?hl=es-419#model_conversion)
# xxd -i converted_model.tflite > model_data.cc
# Out:
# INFO:tensorflow:Assets written to: models/assets
# INFO:tensorflow:Assets written to: C:\Users\Daniela\AppData\Local\Temp\tmpbyiq2bv9\assets
# 18604
